# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
from sklearn.metrics import confusion_matrix, classification_report
import itertools


# Configuration
DATA_DIR = "screw_dataset"
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
EPOCHS = 30

# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## 1. Fonctions de transformation

# %%
def rotate_image(image, angle_degrees):
    return tf.image.rot90(
        image, 
        k=int(round(angle_degrees / 90)) % 4
    )

def adjust_pixels(image, brightness_delta, contrast_factor):
    bright_image = tf.image.adjust_brightness(image, brightness_delta)
    adjusted_image = tf.image.adjust_contrast(bright_image, contrast_factor)
    return tf.clip_by_value(adjusted_image, 0.0, 1.0)

def degrade_quality(image, quality_level):
    if quality_level == 1:
        smaller = tf.image.resize(image, [112, 112])
        degraded = tf.image.resize(smaller, [224, 224])
        return degraded
    
    elif quality_level == 2:
        saturated = tf.image.adjust_saturation(image, 2.0)
        return saturated
    
    elif quality_level == 3:
        noise = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=0.05)
        noisy_img = image + noise
        return tf.clip_by_value(noisy_img, 0.0, 1.0)
    
    return image

# %% [markdown]
# ## 2. Data augmentation

# %%
# Fonction de data augmentation
def data_augmentation(X_train, y_train, BATCH_SIZE=32):
    # Vérifier la forme des données
    print("Forme de X_train:", X_train.shape)
    print("Forme de y_train:", y_train.shape)

    # Trouver les indices des images "bad" et "good"
    bad_indices = np.where(y_train[:, 0] == 0)[0]
    good_indices = np.where(y_train[:, 0] == 1)[0]
    
    X_bad = X_train[bad_indices]
    X_good = X_train[good_indices]

    print(f"Nombre d'images 'bad' avant augmentation: {len(X_bad)}")
    print(f"Nombre d'images 'good' avant augmentation: {len(X_good)}")

    # Définir les transformations
    def rotation_transforms():
        return [
            (lambda img: rotate_image(img, 90), "Rotation 90°"),
            (lambda img: rotate_image(img, 180), "Rotation 180°"),
            (lambda img: rotate_image(img, 270), "Rotation 270°")
        ]

    def pixel_transforms():
        return [
            (lambda img: adjust_pixels(img, 0.2, 1.0), "Plus lumineux"),
            (lambda img: adjust_pixels(img, -0.2, 1.0), "Plus sombre"),
            (lambda img: adjust_pixels(img, 0.0, 1.5), "Plus de contraste"),
            (lambda img: adjust_pixels(img, 0.0, 0.7), "Moins de contraste")
        ]

    def quality_transforms():
        return [
            (lambda img: degrade_quality(img, 1), "Perte de résolution"),
            (lambda img: degrade_quality(img, 2), "Saturation extrême"),
            (lambda img: degrade_quality(img, 3), "Bruit gaussien")
        ]

    def combo_transforms():
        combos = []
        rotations = rotation_transforms()
        pixels = pixel_transforms()
        qualities = quality_transforms()
        
        # Combinaisons rotation + pixel
        for rot in rotations:
            for pix in pixels:
                combos.append((
                    lambda img, r=rot[0], p=pix[0]: p(r(img)), 
                    f"{rot[1]} + {pix[1]}"
                ))
        
        # Combinaisons rotation + qualité
        for rot in rotations:
            for qual in qualities:
                combos.append((
                    lambda img, r=rot[0], q=qual[0]: q(r(img)), 
                    f"{rot[1]} + {qual[1]}"
                ))
        
        return combos

    # Collecter toutes les transformations
    all_transforms = (
        rotation_transforms() + 
        pixel_transforms() + 
        quality_transforms() + 
        combo_transforms()
    )

    # Générer les images augmentées
    X_bad_augmented = []
    y_bad_augmented = []
    
    # Suivre l'utilisation des transformations
    transform_counts = {t[1]: 0 for t in all_transforms}

    # Liste pour stocker les transformations utilisées
    used_transforms = []

    # Générer des augmentations jusqu'à atteindre le nombre d'images 'good'
    np.random.seed(42)
    remaining_count = len(X_good)
    
    while len(X_bad_augmented) < remaining_count:
        # Choisir une image source
        img_source = X_bad[len(X_bad_augmented) % len(X_bad)]
        
        # Créer une liste de transformations disponibles
        available_transforms = [
            t for t in all_transforms 
            if transform_counts[t[1]] < (remaining_count // len(all_transforms) + 1)
        ]
        
        # Réinitialiser si nécessaire
        if not available_transforms:
            transform_counts = {t[1]: 0 for t in all_transforms}
            available_transforms = all_transforms
        
        # Choisir une transformation
        transform, transform_name = random.choice(available_transforms)
        
        # Appliquer la transformation
        transformed_img = transform(img_source)
        
        # Ajouter l'image
        X_bad_augmented.append(transformed_img.numpy())
        y_bad_augmented.append(0)
        
        # Stocker la transformation
        used_transforms.append(transform_name)
        
        # Mettre à jour le compteur
        transform_counts[transform_name] += 1

    # Tronquer pour correspondre exactement au nombre d'images 'good'
    X_bad_augmented = X_bad_augmented[:len(X_good)]
    y_bad_augmented = y_bad_augmented[:len(X_good)]
    used_transforms = used_transforms[:len(X_good)]

    # Convertir en arrays numpy
    X_bad_augmented = np.array(X_bad_augmented)
    y_bad_augmented = np.array(y_bad_augmented).reshape(-1, 1)

    # Combiner avec les images "good"
    X_train_balanced = np.concatenate([X_good, X_bad_augmented])
    y_train_balanced = np.concatenate([
        y_train[good_indices], 
        y_bad_augmented
    ])

    # Mélanger le nouvel ensemble d'entraînement
    indices = np.arange(len(X_train_balanced))
    np.random.shuffle(indices)
    X_train_balanced = X_train_balanced[indices]
    y_train_balanced = y_train_balanced[indices]

    # Créer un nouveau dataset TensorFlow
    train_dataset_balanced = tf.data.Dataset.from_tensor_slices((X_train_balanced, y_train_balanced))
    train_dataset_balanced = train_dataset_balanced.shuffle(buffer_size=len(X_train_balanced)).batch(BATCH_SIZE)

    X_bad_original = X_bad  # Les images "bad" originales
    
    return (X_train_balanced, y_train_balanced, train_dataset_balanced, 
            transform_counts, used_transforms, X_bad_original, X_bad_augmented)

# %% [markdown]
# ## 3. Chargement et Prétraitement des Images

# %%
# Obtenir la liste des noms de fichiers et leurs dossiers d'origine
file_paths = []
folders = []

for class_name in ['bad', 'good']:
    class_dir = os.path.join(DATA_DIR, class_name)
    for img_name in os.listdir(class_dir):
        if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
            file_paths.append(os.path.join(class_dir, img_name))
            folders.append(class_name)

# %%
# Chargement des images
print("Chargement des images...")
dataset = image_dataset_from_directory(
    DATA_DIR,
    labels='inferred',
    label_mode='binary',  # Classification binaire
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=False
)

# Extraction des images et labels
all_images = []
all_labels = []
for images, labels in dataset:
    all_images.append(images.numpy())
    all_labels.append(labels.numpy())

X = np.concatenate(all_images, axis=0) / 255.0  # Normalisation 
y = np.concatenate(all_labels, axis=0)

# Affichage des statistiques de base
print(f"Nombre total d'images: {X.shape[0]}")
print(f"Images 'bad' (label 0): {np.sum(y == 0)}")
print(f"Images 'good' (label 1): {np.sum(y == 1)}")
# Out:
# Chargement des images...
# Found 1152 files belonging to 2 classes.
# Nombre total d'images: 1152
# Images 'bad' (label 0): 285
# Images 'good' (label 1): 867

# %% [markdown]
# ## 4. Mélange et préparation des données

# %%
# Mélange des données
indices = np.arange(X.shape[0])
np.random.seed(42)
np.random.shuffle(indices)
X_shuffled = X[indices]
y_shuffled = y[indices]

# On mélange aussi les chemins de fichiers de la même façon
file_paths = np.array(file_paths)
folders = np.array(folders)
file_paths_shuffled = file_paths[indices]
folders_shuffled = folders[indices]

# Affichage des 10 premiers échantillons après mélange
print("\nPremiers échantillons après mélange:")
print("| N° | Nom de l'image                | Dossier d'origine | Label |")
print("|----|--------------------------------|-------------------|-------|")
for i in range(10):
    img_name = os.path.basename(file_paths_shuffled[i])
    folder = folders_shuffled[i]
    label = int(y_shuffled[i])
    print(f"| {i+1:2d} | {img_name:30s} | {folder:15s} | {label}     |")
# Out:
# Premiers échantillons après mélange:
# | N° | Nom de l'image                | Dossier d'origine | Label |
# |----|--------------------------------|-------------------|-------|
# |  1 | 020_png.rf.bc1d8a583bfdb217fac2f64731e9771e.jpg | bad             | 0     |
# |  2 | 196_png.rf.7fe8531648ca4aada3540a77f0ed51f6.jpg | good            | 1     |
# |  3 | 009_png.rf.4539849089ddf72abf868f1b866a0d09.jpg | good            | 1     |
# |  4 | 006_png.rf.c13a364cc262b36d021c69ab2a8533dc.jpg | bad             | 0     |
# |  5 | 010_png.rf.1b22cf6babd655ecd7b71eff26a6310b.jpg | good            | 1     |
# |  6 | 010_png.rf.49e214452922e22b40fe37eae05704b0.jpg | bad             | 0     |
# |  7 | 032_png.rf.f74158859e091821a14a89d777c86dfa.jpg | good            | 1     |
# |  8 | 210_png.rf.2476a4242693cc1c0b22a415c208ff82.jpg | good            | 1     |
# |  9 | 307_png.rf.2b348fa19f1025ec590df6a0fecba82e.jpg | good            | 1     |
# | 10 | 090_png.rf.7d126610d0db8d47ffec2a9dc9043bae.jpg | good            | 1     |
# /var/folders/c4/gwh8dn4x50x2lbs830bg6dkc0000gn/T/ipykernel_32531/4279012029.py:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label = int(y_shuffled[i])

# %% [markdown]
# ## 6. Division des données

# %%
# Division train/validation/test (70/15/15)
X_train, X_temp, y_train, y_temp, paths_train, paths_temp, folders_train, folders_temp = train_test_split(
    X_shuffled, y_shuffled, file_paths_shuffled, folders_shuffled, train_size=0.7, stratify=y_shuffled, random_state=42
)

X_val, X_test, y_val, y_test, paths_val, paths_test, folders_val, folders_test = train_test_split(
    X_temp, y_temp, paths_temp, folders_temp, train_size=0.5, stratify=y_temp, random_state=42
)

# %% [markdown]
# ## 7. Statistiques des ensembles

# %%
# Statistiques des ensembles
print(f"\nEnsemble d'entraînement: {X_train.shape[0]} images")
print(f"  - Bad (0): {np.sum(y_train == 0)} ({np.mean(y_train == 0)*100:.1f}%)")
print(f"  - Good (1): {np.sum(y_train == 1)} ({np.mean(y_train == 1)*100:.1f}%)")

print(f"\nEnsemble de validation: {X_val.shape[0]} images")
print(f"  - Bad (0): {np.sum(y_val == 0)} ({np.mean(y_val == 0)*100:.1f}%)")
print(f"  - Good (1): {np.sum(y_val == 1)} ({np.mean(y_val == 1)*100:.1f}%)")

print(f"\nEnsemble de test: {X_test.shape[0]} images")
print(f"  - Bad (0): {np.sum(y_test == 0)} ({np.mean(y_test == 0)*100:.1f}%)")
print(f"  - Good (1): {np.sum(y_test == 1)} ({np.mean(y_test == 1)*100:.1f}%)")
# Out:
# Ensemble d'entraînement: 806 images
#   - Bad (0): 199 (24.7%)
#   - Good (1): 607 (75.3%)
#
# Ensemble de validation: 173 images
#   - Bad (0): 43 (24.9%)
#   - Good (1): 130 (75.1%)
#
# Ensemble de test: 173 images
#   - Bad (0): 43 (24.9%)
#   - Good (1): 130 (75.1%)

# %% [markdown]
# ## 8. Création des datasets augmentés et équilibrés

# %%
X_train_balanced, y_train_balanced, train_dataset, transform_counts, used_transforms, X_bad, X_bad_augmented = data_augmentation(X_train, y_train.reshape(-1, 1), BATCH_SIZE)

# Les autres datasets restent inchangés
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# Mise à jour des statistiques pour le nouvel ensemble d'entraînement
print(f"\nEnsemble d'entraînement après augmentation: {X_train_balanced.shape[0]} images")
print(f"  - Bad (0): {np.sum(y_train_balanced == 0)} ({np.mean(y_train_balanced == 0)*100:.1f}%)")
print(f"  - Good (1): {np.sum(y_train_balanced == 1)} ({np.mean(y_train_balanced == 1)*100:.1f}%)")

# Afficher les statistiques des transformations
print("\nUtilisation des transformations:")
for name, count in sorted(transform_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{name}: {count} fois")
# Out:
# Forme de X_train: (806, 224, 224, 3)
# Forme de y_train: (806, 1)
# Nombre d'images 'bad' avant augmentation: 199
# Nombre d'images 'good' avant augmentation: 607
#
# Ensemble d'entraînement après augmentation: 1214 images
#   - Bad (0): 607 (50.0%)
#   - Good (1): 607 (50.0%)
#
# Utilisation des transformations:
# Rotation 90°: 20 fois
# Rotation 180°: 20 fois
# Rotation 270°: 20 fois
# Plus lumineux: 20 fois
# Plus sombre: 20 fois
# Plus de contraste: 20 fois
# Moins de contraste: 20 fois
# Perte de résolution: 20 fois
# Saturation extrême: 20 fois
# Bruit gaussien: 20 fois
# Rotation 90° + Plus lumineux: 20 fois
# Rotation 90° + Plus sombre: 20 fois
# Rotation 90° + Plus de contraste: 20 fois
# Rotation 90° + Moins de contraste: 20 fois
# Rotation 180° + Plus lumineux: 20 fois
# Rotation 180° + Plus sombre: 20 fois
# Rotation 180° + Plus de contraste: 20 fois
# Rotation 180° + Moins de contraste: 20 fois
# Rotation 270° + Plus sombre: 20 fois
# Rotation 270° + Plus de contraste: 20 fois
# Rotation 90° + Perte de résolution: 20 fois
# Rotation 90° + Saturation extrême: 20 fois
# Rotation 180° + Saturation extrême: 20 fois
# Rotation 270° + Perte de résolution: 20 fois
# Rotation 270° + Saturation extrême: 20 fois
# Rotation 270° + Bruit gaussien: 20 fois
# Rotation 180° + Perte de résolution: 19 fois
# Rotation 180° + Bruit gaussien: 19 fois
# Rotation 270° + Plus lumineux: 18 fois
# Rotation 90° + Bruit gaussien: 18 fois
# Rotation 270° + Moins de contraste: 13 fois

# %%
# Visualiser les augmentations
plt.figure(figsize=(20, 15))
visualization_samples = list(zip(X_bad[:5], X_bad_augmented[:5], used_transforms[:5]))

for i, (original, transformed, transform_type) in enumerate(visualization_samples):
    # Image originale
    plt.subplot(5, 2, i*2+1)
    plt.imshow(original)
    plt.title(f"Image originale {i+1}")
    plt.axis('off')
    
    # Image transformée
    plt.subplot(5, 2, i*2+2)
    plt.imshow(transformed)
    plt.title(transform_type)
    plt.axis('off')

plt.suptitle("Exemples de transformations d'images 'bad'", fontsize=16)
plt.tight_layout()
plt.savefig('augmented_bad_images.png')
plt.show()

# %% [markdown]
# # Modèle retravaillé

# %% [markdown]
# ## 1. Définition du modèle CNN retravaillé
#
# ### Améliorations principales :
#
# - binary_crossentropy pour la perte
#
# - sigmoid pour la sortie binaire
#
# - Plus de couches convolutives
#
# - Batch Normalization pour stabiliser l'apprentissage
#
# - Dropout pour réduire le surapprentissage
#
# - Métriques supplémentaires (précision, recall, AUC)
#
#
# (Note : Convolutional Neural Network (CNN), ou réseau de neurones convolutif en français, est une architecture spécifique de réseaux de neurones profonds utilisée en apprentissage automatique et notamment en Deep Learning.)

# %%
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(1, activation='sigmoid')
])

# Compiler avec une pondération des classes
class_weights = {0: 1.5, 1: 1.0}  # Donner plus de poids à la classe minoritaire

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', 'precision', 'recall'],
    weighted_metrics=['accuracy', 'precision', 'recall']
)
# Out:
# /Users/emmacoco/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## 2. Callbacks

# %%
# Définition des callbacks
callbacks = [
    # Early Stopping: arrête l'entraînement si aucune amélioration n'est constatée
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True
    ),
    
    # ReduceLROnPlateau: réduit le taux d'apprentissage quand les métriques stagnent
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-6,
        verbose=1
    ),
    
    # ModelCheckpoint: sauvegarde le meilleur modèle pendant l'entraînement
    tf.keras.callbacks.ModelCheckpoint(
        'best_screw_model.h5',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

# %% [markdown]
# ## 3. Entraînement du modèle

# %%
# Entraînement avec les poids de classe
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=30,
    class_weight=class_weights,
    callbacks=callbacks
)

# Charger le meilleur modèle sauvegardé
model = tf.keras.models.load_model('best_screw_model.h5')
# Out:
# Epoch 1/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.5752 - loss: 10.4760 - precision: 0.6038 - recall: 0.5172 - weighted_accuracy: 0.5873 - weighted_precision: 0.5044 - weighted_recall: 0.5172
# Epoch 1: val_loss improved from inf to 2.07928, saving model to best_screw_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 719ms/step - accuracy: 0.5759 - loss: 10.4383 - precision: 0.6042 - recall: 0.5175 - weighted_accuracy: 0.5880 - weighted_precision: 0.5049 - weighted_recall: 0.5175 - val_accuracy: 0.4393 - val_loss: 2.0793 - val_precision: 0.8511 - val_recall: 0.3077 - val_weighted_accuracy: 0.4393 - val_weighted_precision: 0.8511 - val_weighted_recall: 0.3077 - learning_rate: 0.0010
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.6487 - loss: 6.1302 - precision: 0.6774 - recall: 0.5692 - weighted_accuracy: 0.6645 - weighted_precision: 0.5835 - weighted_recall: 0.5692
# Epoch 2: val_loss improved from 2.07928 to 1.93863, saving model to best_screw_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 696ms/step - accuracy: 0.6493 - loss: 6.1102 - precision: 0.6780 - recall: 0.5701 - weighted_accuracy: 0.6651 - weighted_precision: 0.5841 - weighted_recall: 0.5701 - val_accuracy: 0.2486 - val_loss: 1.9386 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.6869 - loss: 4.1528 - precision: 0.7125 - recall: 0.5972 - weighted_accuracy: 0.7038 - weighted_precision: 0.6234 - weighted_recall: 0.5972
# Epoch 3: val_loss did not improve from 1.93863
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 677ms/step - accuracy: 0.6867 - loss: 4.1613 - precision: 0.7123 - recall: 0.5976 - weighted_accuracy: 0.7035 - weighted_precision: 0.6232 - weighted_recall: 0.5976 - val_accuracy: 0.2486 - val_loss: 38.3514 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.6987 - loss: 3.1333 - precision: 0.7262 - recall: 0.6181 - weighted_accuracy: 0.7141 - weighted_precision: 0.6389 - weighted_recall: 0.6181
# Epoch 4: val_loss did not improve from 1.93863
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 712ms/step - accuracy: 0.6983 - loss: 3.1302 - precision: 0.7258 - recall: 0.6183 - weighted_accuracy: 0.7137 - weighted_precision: 0.6384 - weighted_recall: 0.6183 - val_accuracy: 0.2486 - val_loss: 25.9009 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.6945 - loss: 2.5419 - precision: 0.7187 - recall: 0.6049 - weighted_accuracy: 0.7115 - weighted_precision: 0.6305 - weighted_recall: 0.6049
# Epoch 5: val_loss did not improve from 1.93863
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 727ms/step - accuracy: 0.6946 - loss: 2.5379 - precision: 0.7191 - recall: 0.6054 - weighted_accuracy: 0.7116 - weighted_precision: 0.6309 - weighted_recall: 0.6054 - val_accuracy: 0.2486 - val_loss: 10.4993 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.7162 - loss: 1.6140 - precision: 0.7222 - recall: 0.6841 - weighted_accuracy: 0.7225 - weighted_precision: 0.6344 - weighted_recall: 0.6841
# Epoch 6: val_loss did not improve from 1.93863
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 665ms/step - accuracy: 0.7162 - loss: 1.6119 - precision: 0.7227 - recall: 0.6833 - weighted_accuracy: 0.7226 - weighted_precision: 0.6350 - weighted_recall: 0.6833 - val_accuracy: 0.2486 - val_loss: 54.5119 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - accuracy: 0.7082 - loss: 0.8387 - precision: 0.7957 - recall: 0.5713 - weighted_accuracy: 0.7359 - weighted_precision: 0.7223 - weighted_recall: 0.5713
# Epoch 7: val_loss did not improve from 1.93863
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 656ms/step - accuracy: 0.7082 - loss: 0.8403 - precision: 0.7956 - recall: 0.5712 - weighted_accuracy: 0.7359 - weighted_precision: 0.7221 - weighted_recall: 0.5712 - val_accuracy: 0.2601 - val_loss: 8.1496 - val_precision: 1.0000 - val_recall: 0.0154 - val_weighted_accuracy: 0.2601 - val_weighted_precision: 1.0000 - val_weighted_recall: 0.0154 - learning_rate: 0.0010
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.7388 - loss: 0.8867 - precision: 0.7441 - recall: 0.7535 - weighted_accuracy: 0.7361 - weighted_precision: 0.6611 - weighted_recall: 0.7535
# Epoch 8: val_loss improved from 1.93863 to 0.87629, saving model to best_screw_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 667ms/step - accuracy: 0.7391 - loss: 0.8845 - precision: 0.7439 - recall: 0.7543 - weighted_accuracy: 0.7364 - weighted_precision: 0.6608 - weighted_recall: 0.7543 - val_accuracy: 0.4682 - val_loss: 0.8763 - val_precision: 0.8065 - val_recall: 0.3846 - val_weighted_accuracy: 0.4682 - val_weighted_precision: 0.8065 - val_weighted_recall: 0.3846 - learning_rate: 0.0010
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.7376 - loss: 0.9487 - precision: 0.7178 - recall: 0.7879 - weighted_accuracy: 0.7274 - weighted_precision: 0.6293 - weighted_recall: 0.7879
# Epoch 9: val_loss did not improve from 0.87629
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 668ms/step - accuracy: 0.7379 - loss: 0.9442 - precision: 0.7178 - recall: 0.7887 - weighted_accuracy: 0.7276 - weighted_precision: 0.6294 - weighted_recall: 0.7887 - val_accuracy: 0.2890 - val_loss: 0.9750 - val_precision: 0.7333 - val_recall: 0.0846 - val_weighted_accuracy: 0.2890 - val_weighted_precision: 0.7333 - val_weighted_recall: 0.0846 - learning_rate: 0.0010
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.7736 - loss: 0.6432 - precision: 0.7371 - recall: 0.8456 - weighted_accuracy: 0.7594 - weighted_precision: 0.6518 - weighted_recall: 0.8456
# Epoch 10: val_loss improved from 0.87629 to 0.72682, saving model to best_screw_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 685ms/step - accuracy: 0.7736 - loss: 0.6434 - precision: 0.7370 - recall: 0.8462 - weighted_accuracy: 0.7593 - weighted_precision: 0.6515 - weighted_recall: 0.8462 - val_accuracy: 0.5087 - val_loss: 0.7268 - val_precision: 0.7320 - val_recall: 0.5462 - val_weighted_accuracy: 0.5087 - val_weighted_precision: 0.7320 - val_weighted_recall: 0.5462 - learning_rate: 0.0010
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.7767 - loss: 0.6472 - precision: 0.7267 - recall: 0.8838 - weighted_accuracy: 0.7555 - weighted_precision: 0.6396 - weighted_recall: 0.8838
# Epoch 11: val_loss did not improve from 0.72682
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 735ms/step - accuracy: 0.7765 - loss: 0.6477 - precision: 0.7266 - recall: 0.8836 - weighted_accuracy: 0.7553 - weighted_precision: 0.6394 - weighted_recall: 0.8836 - val_accuracy: 0.5087 - val_loss: 1.6473 - val_precision: 0.7228 - val_recall: 0.5615 - val_weighted_accuracy: 0.5087 - val_weighted_precision: 0.7228 - val_weighted_recall: 0.5615 - learning_rate: 0.0010
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - accuracy: 0.7596 - loss: 0.5896 - precision: 0.7216 - recall: 0.8401 - weighted_accuracy: 0.7436 - weighted_precision: 0.6337 - weighted_recall: 0.8401
# Epoch 12: val_loss did not improve from 0.72682
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 672ms/step - accuracy: 0.7602 - loss: 0.5899 - precision: 0.7223 - recall: 0.8404 - weighted_accuracy: 0.7442 - weighted_precision: 0.6344 - weighted_recall: 0.8404 - val_accuracy: 0.4335 - val_loss: 3.6093 - val_precision: 0.6633 - val_recall: 0.5000 - val_weighted_accuracy: 0.4335 - val_weighted_precision: 0.6633 - val_weighted_recall: 0.5000 - learning_rate: 0.0010
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.7816 - loss: 0.5802 - precision: 0.7312 - recall: 0.8311 - weighted_accuracy: 0.7725 - weighted_precision: 0.6462 - weighted_recall: 0.8311
# Epoch 13: val_loss did not improve from 0.72682
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 710ms/step - accuracy: 0.7819 - loss: 0.5809 - precision: 0.7316 - recall: 0.8324 - weighted_accuracy: 0.7726 - weighted_precision: 0.6466 - weighted_recall: 0.8324 - val_accuracy: 0.6532 - val_loss: 0.7708 - val_precision: 0.7273 - val_recall: 0.8615 - val_weighted_accuracy: 0.6532 - val_weighted_precision: 0.7273 - val_weighted_recall: 0.8615 - learning_rate: 0.0010
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.7745 - loss: 0.5353 - precision: 0.7095 - recall: 0.9117 - weighted_accuracy: 0.7486 - weighted_precision: 0.6203 - weighted_recall: 0.9117
# Epoch 14: val_loss did not improve from 0.72682
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 724ms/step - accuracy: 0.7746 - loss: 0.5359 - precision: 0.7098 - recall: 0.9115 - weighted_accuracy: 0.7487 - weighted_precision: 0.6207 - weighted_recall: 0.9115 - val_accuracy: 0.2486 - val_loss: 124.3761 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 663ms/step - accuracy: 0.7854 - loss: 0.5681 - precision: 0.7104 - recall: 0.9391 - weighted_accuracy: 0.7562 - weighted_precision: 0.6208 - weighted_recall: 0.9391
# Epoch 15: val_loss did not improve from 0.72682
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 678ms/step - accuracy: 0.7855 - loss: 0.5690 - precision: 0.7109 - recall: 0.9386 - weighted_accuracy: 0.7564 - weighted_precision: 0.6214 - weighted_recall: 0.9386 - val_accuracy: 0.7110 - val_loss: 0.7478 - val_precision: 0.7469 - val_recall: 0.9308 - val_weighted_accuracy: 0.7110 - val_weighted_precision: 0.7469 - val_weighted_recall: 0.9308 - learning_rate: 0.0010
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.7833 - loss: 0.5589 - precision: 0.7238 - recall: 0.8944 - weighted_accuracy: 0.7618 - weighted_precision: 0.6361 - weighted_recall: 0.8944
# Epoch 16: val_loss improved from 0.72682 to 0.67703, saving model to best_screw_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 692ms/step - accuracy: 0.7831 - loss: 0.5601 - precision: 0.7238 - recall: 0.8944 - weighted_accuracy: 0.7616 - weighted_precision: 0.6361 - weighted_recall: 0.8944 - val_accuracy: 0.7110 - val_loss: 0.6770 - val_precision: 0.7597 - val_recall: 0.9000 - val_weighted_accuracy: 0.7110 - val_weighted_precision: 0.7597 - val_weighted_recall: 0.9000 - learning_rate: 0.0010
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.7826 - loss: 0.6189 - precision: 0.7286 - recall: 0.8980 - weighted_accuracy: 0.7596 - weighted_precision: 0.6418 - weighted_recall: 0.8980
# Epoch 17: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 702ms/step - accuracy: 0.7820 - loss: 0.6219 - precision: 0.7281 - recall: 0.8977 - weighted_accuracy: 0.7589 - weighted_precision: 0.6412 - weighted_recall: 0.8977 - val_accuracy: 0.2486 - val_loss: 625.1362 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.7562 - loss: 0.6954 - precision: 0.7207 - recall: 0.8304 - weighted_accuracy: 0.7414 - weighted_precision: 0.6326 - weighted_recall: 0.8304
# Epoch 18: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 684ms/step - accuracy: 0.7565 - loss: 0.6954 - precision: 0.7207 - recall: 0.8316 - weighted_accuracy: 0.7415 - weighted_precision: 0.6326 - weighted_recall: 0.8316 - val_accuracy: 0.2486 - val_loss: 366.6238 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.7619 - loss: 0.8321 - precision: 0.7060 - recall: 0.8540 - weighted_accuracy: 0.7448 - weighted_precision: 0.6163 - weighted_recall: 0.8540
# Epoch 19: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 664ms/step - accuracy: 0.7624 - loss: 0.8285 - precision: 0.7070 - recall: 0.8541 - weighted_accuracy: 0.7454 - weighted_precision: 0.6174 - weighted_recall: 0.8541 - val_accuracy: 0.2486 - val_loss: 115.4679 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 20/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.7787 - loss: 0.6692 - precision: 0.7247 - recall: 0.9078 - weighted_accuracy: 0.7524 - weighted_precision: 0.6372 - weighted_recall: 0.9078
# Epoch 20: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 689ms/step - accuracy: 0.7787 - loss: 0.6696 - precision: 0.7250 - recall: 0.9068 - weighted_accuracy: 0.7526 - weighted_precision: 0.6376 - weighted_recall: 0.9068 - val_accuracy: 0.2486 - val_loss: 1854.8658 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 21/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.7881 - loss: 0.6490 - precision: 0.7193 - recall: 0.9500 - weighted_accuracy: 0.7557 - weighted_precision: 0.6313 - weighted_recall: 0.9500
# Epoch 21: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 761ms/step - accuracy: 0.7881 - loss: 0.6502 - precision: 0.7193 - recall: 0.9498 - weighted_accuracy: 0.7557 - weighted_precision: 0.6313 - weighted_recall: 0.9498 - val_accuracy: 0.2486 - val_loss: 1674.4175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 22/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.7948 - loss: 0.5888 - precision: 0.7260 - recall: 0.9670 - weighted_accuracy: 0.7591 - weighted_precision: 0.6388 - weighted_recall: 0.9670
# Epoch 22: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 683ms/step - accuracy: 0.7947 - loss: 0.5893 - precision: 0.7257 - recall: 0.9670 - weighted_accuracy: 0.7590 - weighted_precision: 0.6385 - weighted_recall: 0.9670 - val_accuracy: 0.2486 - val_loss: 874.4736 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 23/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.7682 - loss: 0.6045 - precision: 0.6977 - recall: 0.8864 - weighted_accuracy: 0.7463 - weighted_precision: 0.6062 - weighted_recall: 0.8864
# Epoch 23: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 669ms/step - accuracy: 0.7684 - loss: 0.6046 - precision: 0.6984 - recall: 0.8868 - weighted_accuracy: 0.7465 - weighted_precision: 0.6070 - weighted_recall: 0.8868 - val_accuracy: 0.2486 - val_loss: 540.9270 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_weighted_accuracy: 0.2486 - val_weighted_precision: 0.0000e+00 - val_weighted_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 24/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.7906 - loss: 0.6116 - precision: 0.7176 - recall: 0.9506 - weighted_accuracy: 0.7590 - weighted_precision: 0.6291 - weighted_recall: 0.9506
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 24: val_loss did not improve from 0.67703
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 672ms/step - accuracy: 0.7910 - loss: 0.6104 - precision: 0.7183 - recall: 0.9503 - weighted_accuracy: 0.7596 - weighted_precision: 0.6299 - weighted_recall: 0.9503 - val_accuracy: 0.3237 - val_loss: 7.1266 - val_precision: 0.7407 - val_recall: 0.1538 - val_weighted_accuracy: 0.3237 - val_weighted_precision: 0.7407 - val_weighted_recall: 0.1538 - learning_rate: 0.0010
# Epoch 25/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.8321 - loss: 0.4764 - precision: 0.7636 - recall: 0.9656 - weighted_accuracy: 0.8050 - weighted_precision: 0.6833 - weighted_recall: 0.9656
# Epoch 25: val_loss improved from 0.67703 to 0.63919, saving model to best_screw_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 404s 11s/step - accuracy: 0.8317 - loss: 0.4776 - precision: 0.7635 - recall: 0.9649 - weighted_accuracy: 0.8048 - weighted_precision: 0.6831 - weighted_recall: 0.9649 - val_accuracy: 0.7399 - val_loss: 0.6392 - val_precision: 0.7515 - val_recall: 0.9769 - val_weighted_accuracy: 0.7399 - val_weighted_precision: 0.7515 - val_weighted_recall: 0.9769 - learning_rate: 5.0000e-04
# Epoch 26/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.8421 - loss: 0.4932 - precision: 0.7867 - recall: 0.9579 - weighted_accuracy: 0.8177 - weighted_precision: 0.7115 - weighted_recall: 0.9579
# Epoch 26: val_loss did not improve from 0.63919
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 720ms/step - accuracy: 0.8415 - loss: 0.4932 - precision: 0.7857 - recall: 0.9578 - weighted_accuracy: 0.8170 - weighted_precision: 0.7103 - weighted_recall: 0.9578 - val_accuracy: 0.7514 - val_loss: 0.6448 - val_precision: 0.7574 - val_recall: 0.9846 - val_weighted_accuracy: 0.7514 - val_weighted_precision: 0.7574 - val_weighted_recall: 0.9846 - learning_rate: 5.0000e-04
# Epoch 27/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - accuracy: 0.8385 - loss: 0.4333 - precision: 0.7839 - recall: 0.9404 - weighted_accuracy: 0.8178 - weighted_precision: 0.7075 - weighted_recall: 0.9404
# Epoch 27: val_loss did not improve from 0.63919
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 753ms/step - accuracy: 0.8385 - loss: 0.4332 - precision: 0.7840 - recall: 0.9400 - weighted_accuracy: 0.8179 - weighted_precision: 0.7077 - weighted_recall: 0.9400 - val_accuracy: 0.6821 - val_loss: 0.7514 - val_precision: 0.7517 - val_recall: 0.8615 - val_weighted_accuracy: 0.6821 - val_weighted_precision: 0.7517 - val_weighted_recall: 0.8615 - learning_rate: 5.0000e-04
# Epoch 28/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - accuracy: 0.8302 - loss: 0.4482 - precision: 0.7721 - recall: 0.9368 - weighted_accuracy: 0.8088 - weighted_precision: 0.6932 - weighted_recall: 0.9368
# Epoch 28: val_loss did not improve from 0.63919
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 559ms/step - accuracy: 0.8303 - loss: 0.4485 - precision: 0.7722 - recall: 0.9368 - weighted_accuracy: 0.8090 - weighted_precision: 0.6934 - weighted_recall: 0.9368 - val_accuracy: 0.6763 - val_loss: 0.7325 - val_precision: 0.7721 - val_recall: 0.8077 - val_weighted_accuracy: 0.6763 - val_weighted_precision: 0.7721 - val_weighted_recall: 0.8077 - learning_rate: 5.0000e-04
# Epoch 29/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.8414 - loss: 0.4540 - precision: 0.7897 - recall: 0.9416 - weighted_accuracy: 0.8207 - weighted_precision: 0.7148 - weighted_recall: 0.9416
# Epoch 29: val_loss did not improve from 0.63919
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 570ms/step - accuracy: 0.8413 - loss: 0.4541 - precision: 0.7895 - recall: 0.9417 - weighted_accuracy: 0.8207 - weighted_precision: 0.7145 - weighted_recall: 0.9417 - val_accuracy: 0.6994 - val_loss: 0.9638 - val_precision: 0.7826 - val_recall: 0.8308 - val_weighted_accuracy: 0.6994 - val_weighted_precision: 0.7826 - val_weighted_recall: 0.8308 - learning_rate: 5.0000e-04
# Epoch 30/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.8266 - loss: 0.4511 - precision: 0.7657 - recall: 0.9397 - weighted_accuracy: 0.8041 - weighted_precision: 0.6856 - weighted_recall: 0.9397
# Epoch 30: val_loss did not improve from 0.63919
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 575ms/step - accuracy: 0.8267 - loss: 0.4509 - precision: 0.7662 - recall: 0.9391 - weighted_accuracy: 0.8044 - weighted_precision: 0.6862 - weighted_recall: 0.9391 - val_accuracy: 0.7572 - val_loss: 0.7605 - val_precision: 0.7588 - val_recall: 0.9923 - val_weighted_accuracy: 0.7572 - val_weighted_precision: 0.7588 - val_weighted_recall: 0.9923 - learning_rate: 5.0000e-04
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 11
#       2 history = model.fit(
#       3     train_dataset,
#       4     validation_data=val_dataset,
#    (...)
#       7     callbacks=callbacks
#       8 )
#      10 # Charger le meilleur modèle sauvegardé
# ---> 11 model = tf.keras.models.load_model('best_screw_model.h5')
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/saving/saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/legacy/saving/legacy_h5_format.py:155, in load_model_from_hdf5(filepath, custom_objects, compile)
#     151 training_config = json_utils.decode(training_config)
#     153 # Compile model.
#     154 model.compile(
# --> 155     **saving_utils.compile_args_from_training_config(
#     156         training_config, custom_objects
#     157     )
#     158 )
#     159 saving_utils.try_build_compiled_arguments(model)
#     161 # Set optimizer weights.
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/legacy/saving/saving_utils.py:145, in compile_args_from_training_config(training_config, custom_objects)
#     143     loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     144     # Ensure backwards compatibility for losses in legacy H5 files
# --> 145     loss = _resolve_compile_arguments_compat(loss, loss_config, losses)
#     147 # Recover metrics.
#     148 metrics = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/legacy/saving/saving_utils.py:245, in _resolve_compile_arguments_compat(obj, obj_config, module)
#     237 """Resolves backwards compatibility issues with training config arguments.
#     238
#     239 This helper function accepts built-in Keras modules such as optimizers,
#    (...)
#     242 this does nothing.
#     243 """
#     244 if isinstance(obj, str) and obj not in module.ALL_OBJECTS_DICT:
# --> 245     obj = module.get(obj_config["config"]["name"])
#     246 return obj
#
# TypeError: string indices must be integers

# %% [markdown]
# ## 4. Visualisations

# %%
# Visualisation des courbes d'apprentissage
plt.figure(figsize=(15, 5))

# Graphique de l'accuracy
plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Précision')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()
plt.grid(True)

# Graphique de la perte
plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Perte')
plt.xlabel('Époque')
plt.ylabel('Perte')
plt.legend()
plt.grid(True)

# Graphique de precision et recall
plt.subplot(1, 3, 3)
plt.plot(history.history['precision'], label='Précision (Train)')
plt.plot(history.history['recall'], label='Rappel (Train)')
plt.plot(history.history['val_precision'], label='Précision (Val)')
plt.plot(history.history['val_recall'], label='Rappel (Val)')
plt.title('Précision et Rappel')
plt.xlabel('Époque')
plt.ylabel('Valeur')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('courbes_apprentissage.png')
plt.show()

# %% [markdown]
# ## 5. Évaluation sur l'ensemble de test

# %%
# Évaluation sur l'ensemble de test
test_results = model.evaluate(test_dataset, verbose=1)
print("\nRésultats sur l'ensemble de test:")
for name, value in zip(model.metrics_names, test_results):
    print(f"{name}: {value:.4f}")

# Prédictions sur l'ensemble de test
y_pred = model.predict(test_dataset)
y_pred_classes = (y_pred > 0.5).astype(int)

# Obtenir les vraies étiquettes
y_true = []
for _, labels in test_dataset:
    y_true.extend(labels.numpy())
y_true = np.array(y_true)

# Matrice de confusion
def plot_confusion_matrix(cm, classes, normalize=False, title='Matrice de confusion', cmap=plt.cm.Blues):
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    
    plt.tight_layout()
    plt.ylabel('Vraie classe')
    plt.xlabel('Classe prédite')
    return plt

cm = confusion_matrix(y_true, y_pred_classes)
class_names = ['Bad', 'Good']  # 0 = Bad, 1 = Good
plot_confusion_matrix(cm, classes=class_names, title='Matrice de confusion')
plt.savefig('matrice_confusion.png')
plt.show()

# Rapport de classification
report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("\nRapport de classification:")
print(report)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7159 - loss: 1.0238 - precision_10: 0.7587 - precision_11: 0.7587 - recall_10: 0.9158 - recall_11: 0.9158 - weighted_accuracy: 0.7159
#
# Résultats sur l'ensemble de test:
# loss: 0.9565
# compile_metrics: 0.7168
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Rapport de classification:
#               precision    recall  f1-score   support
#
#          Bad       0.31      0.12      0.17        43
#         Good       0.76      0.92      0.83       130
#
#     accuracy                           0.72       173
#    macro avg       0.54      0.52      0.50       173
# weighted avg       0.65      0.72      0.67       173

# %% [markdown]
# ## Visualisation des données mal classifiées

# %%
# Visualiser quelques exemples mal classés
misclassified_indices = []

# Collecter les indices des exemples mal classés
y_pred_flat = y_pred.flatten()
current_idx = 0

for x_batch, y_batch in test_dataset:
    y_batch_np = y_batch.numpy().flatten()
    pred_batch = (y_pred_flat[current_idx:current_idx+len(y_batch_np)] > 0.5).astype(int)
    
    for i in range(len(y_batch_np)):
        if pred_batch[i] != y_batch_np[i]:
            misclassified_indices.append((current_idx + i, x_batch[i].numpy(), 
                                          y_batch_np[i], pred_batch[i]))
    
    current_idx += len(y_batch_np)

# Afficher quelques exemples mal classés
plt.figure(figsize=(15, 10))
num_examples = min(8, len(misclassified_indices))

for i in range(num_examples):
    idx, img, true_label, pred_label = misclassified_indices[i]
    plt.subplot(2, 4, i+1)
    plt.imshow(img)
    plt.title(f"Vraie: {class_names[int(true_label)]}\nPrédite: {class_names[int(pred_label)]}")
    plt.axis('off')

plt.tight_layout()
plt.savefig('exemples_mal_classes.png')
plt.show()

print(f"\nNombre total d'exemples mal classés: {len(misclassified_indices)} sur {len(y_true)} ({len(misclassified_indices)/len(y_true)*100:.1f}%)")
# Out:
# Nombre total d'exemples mal classés: 49 sur 173 (28.3%)
